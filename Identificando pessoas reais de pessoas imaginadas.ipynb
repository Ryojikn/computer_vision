# %% [markdown]
# ### Você é capaz de descobrir qual das pessoas abaixo é verdadeira?
#
# A área de visão computacional abrange muitos segmentos, e possuímos uma coletânea imensa de arquiteturas de redes neurais capazes de executarem as tarefas mais aleatórias possíveis.
#
# Dentre elas, é possível treinar uma rede neural com inúmeras fotos de pessoas, e deixar que esta rede aprenda suas características, e o que determina ou não uma pessoa.
#
#
# Com isso em mãos, você consegue dizer qual das pessoas abaixo é verdadeira?

# %% [markdown]
# ### Qual das quatro pessoas abaixo é uma pessoa real?

# %% [markdown]
# ![image 1](https://github.com/Ryojikn/computer_vision/blob/master/raw_imgs/donotexist_1.jpg?raw=True)
# ![image 2](https://github.com/Ryojikn/computer_vision/blob/master/raw_imgs/donotexist_2.jpg?raw=True)
# ![image 3](https://github.com/Ryojikn/computer_vision/blob/master/raw_imgs/donotexist_3.jpg?raw=True)
# ![image 4](https://github.com/Ryojikn/computer_vision/blob/master/raw_imgs/donotexist_4.jpg?raw=True)

# %% [markdown]
# ### E aí, algum palpite?

# %% [markdown]
# A resposta final é que **nenhuma** delas existe, estas pessoas são composições feitas por uma rede neural com arquitetura GAN, apresentada por Tero Karras et al., um time de pesquisadores da **NVIDIA**.
#
# Essa brincadeira está disponível no site: https://thispersondoesnotexist.com/

# %% [markdown]
# ### Entenda um pouco mais como funciona a StyleGAN
#
# O paper oficial está neste link: https://arxiv.org/abs/1912.04958
#
# Mas você também pode assistir os vídeos abaixos pra entender um pouco mais.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('u8qPvzk0AfY', width=800, height=300)

# %%
YouTubeVideo('dCKbRCUyop8', width=800, height=300)

# %% [markdown]
# ### E por fim, o que eu considero o melhor resumo de papers de um jeito simplificado

# %%
YouTubeVideo('SWoravHhsUU', width=800, height=300)
